# %% [markdown]
# <a href="https://colab.research.google.com/github/ccastelblancob/Inteligencia-artificial-curso-2023-2/blob/Tareas/Jugando_con_redes_neuronales_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Inteligencia Artificial
#
#  Cristian Felipe Castelblanco Benavides

# %% [markdown]
# **Jugando con redes neuronales. Playground**
# Este reporte se enfoca en explorar diversas estrategias para la clasificación de la data en Playground de Tensorflow, utilizando diferentes redes neuronales, variando el número de capas ocultas y además utilizando diferentes features para el input del modelo.
#
# Para esto vamos a contar solo con dos categorias de datos: aquellos etiquetados con el valor "1" (representados en color azul) y aquellos con la etiqueta "-1" (visualizados en color anaranjado).
#
#
#
# 1.   **Data en forma de círculo**
#  La primera clasificación que haremos es cuando el conjunto de datos tiene forma de círculo, como se ve a continuación.

# %% [markdown]
# ![c.png](data:image/png;base64,...)
#
# Figura 1

# %% [markdown]
# El primer intento para separar esta data va hacer considerando 4 features las cuales son $x_1, x_2, x^{2}_1 \text{ y } x^{2}_2$, ya que se asemeja a la ecuación de una circunferencia. Los resultados se muestran en la figura 2.

# %% [markdown]
# ![d.png](data:image/png;base64,...)
# Figura 2

# %% [markdown]
# Como era de esperar, solo considerando la 4 features nombradas anteriormente se pudo separa la data sin necesidad de ninguna capa oculta. Además  solo  se necesitaron 29 epoch para tener un test loss de 0.018, el cual es muy bueno.
#
# Ahora vamos a considerar solo dos features $x_1 \text{ y } x_2$, una capa oculta con tres redes neuronales y la función de activación $Tanh$ para clasificar la misma data.

# %% [markdown]
# ![e.png](data:image/png;base64,...)
# Figura 3

# %% [markdown]
# Como se ilustra en la Figura 3, se requirieron 767 epoch para lograr un test loss de 0.018. A partir de este análisis, se puede extraer una conclusión de gran relevancia: no siempre es cierto que un modelo con un mayor número de capas produzca mejores resultados. Esto se evidencia aún más si consideramos la prueba anterior, como se muestra en la Figura 2, donde se alcanzó un test loss de 0.018 con tan solo 29 epoch y sin ninguna capa oculta.
#
# Ahora vamos a variar el número de capas ocultas en el modelo para así conseguir el mismo test loss con menos epoch.

# %% [markdown]
# ![f.png](data:image/png;base64,...)
# Figura 4

# %% [markdown]
# Tal como se aprecia en la Figura 4, al emplear un modelo que incorpora 4 features, dos capas ocultas, cada una con 8 neuronas y la función de activación $Tanh$, conseguimos alcanzar un test loss de 0.018 en tan solo 9 epoch. Este resultado supera significativamente al del primer modelo que no incluía capas ocultas. Este hallazgo resalta una conclusión relevante: la combinación adecuada de características y capas ocultas puede conducir a la creación de modelos más efectivos.
#
#
#
#
# 2.   **Data en forma de espiral**
#
# La segunda clasificación que haremos es cuando el conjuntos de datos tiene forma de espiral, como se ve acontinuación.

# %% [markdown]
# ![g.png](data:image/png;base64,...)
#
# Figura 5

# %% [markdown]
# La elección inicial de arquitectura será la que se muestra en la Figura 4, dado que esta ha demostrado un buen desempeño en la clasificación de datos con una estructura circular.

# %% [markdown]
# ![h.png](data:image/png;base64,...)
#
# Figura 6

# %% [markdown]
# Se requirieron 541 epoch para alcanzar un test loss de 0.018 utilizando esta arquitectura. A partir de este resultado, podemos deducir que una arquitectura de red neuronal que demostró un rendimiento sólido en la clasificación de un tipo de estructura de datos no necesariamente replicará el mismo rendimiento en otra estructura de datos. Esto es evidente al comparar el hecho de que, para la estructura de datos circular, solo se necesitaron 9 epoch para lograr un test loss de 0.018.
#
# En la próxima arquitectura, como se ilustra en la Figura 6, se incorporará una capa oculta adicional con 8 neuronas. Esto se realizará con el propósito de llevar a cabo una comparación con la arquitectura representada en la Figura 5.

# %% [markdown]
# ![i.png](data:image/png;base64,...)
#
# Figura 7

# %% [markdown]
# Una conclusión relevante que podemos extraer de esta comparación es que la adición de capas ocultas no garantiza necesariamente que el modelo logre un test loss en la fase de prueba con menos epoch. Esto es evidente al observar que la arquitectura de la Figura 5 logró test loss de 0.018 con 541 epoch, mientras que la arquitectura de la Figura 6 alcanzó un test loss de 0.030 con 597 épocas, lo que indica un rendimiento inferior en términos de eficiencia, aunque sea casi despreciable.
#
#
#
# 3.  **Comentarios finales**
#
# Playground de TensorFlow sepresenta como una herramienta invaluable para facilitar la comprensión de conceptos fundamentales relacionados con las arquitecturas de redes neuronales, las capas ocultas, las variadas funciones de activación y la selección de características. Asimismo, esta plataforma ofrece la posibilidad de utilizarla como un primer paso en la resolución de problemas de clasificación, particularmente cuando la estructura de los datos se asemeja a la que se encuentra en la herramienta. Su accesibilidad y capacidad para experimentar hacen que sea una opción poderosa tanto para el aprendizaje como para la resolución inicial de desafíos de aprendizaje automático con redes neuronales.
